# %% [markdown]
# ## GSE239626

# %% [markdown]
# | GEO Accession | Provided Information | Technology Used | Type of Data | Tissue/Cell Type Analyzed | Specific Samples |
# |---------------|----------------------|------------------|--------------|----------------------------|------------------|
# | GSE239626     | Gene expression profiling using high-throughput sequencing (scRNA-seq and CITE-seq) | scRNA-seq, CITE-seq | Processed matrix (gene expression) | Peripheral blood mononuclear cells (PBMCs) | Multiple sclerosis patients treated with high-dose vitamin D and placebo |

# %%
from GSE239626.load_GSE239626 import load_GSE239626

genomic_matrix_df, gene_expression_df, antibody_capture_df, family_phenotype_df = load_GSE239626()
# 7 min to load first time, 10 sec for subsequent runs
# Out:
# c:\Users\giuli\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
help(load_GSE239626)
# Out:
# Help on function load_GSE239626 in module GSE239626.load_GSE239626:
#
# load_GSE239626()
#     Load data from GSE239626 dataset
#
#     Returns:
#         genomic_matrix_df (pd.DataFrame): Genomic matrix data
#         gene_expression_df (pd.DataFrame): Gene expression data, subset of genomic matrix
#         antibody_capture_df (pd.DataFrame): Antibody capture data, subset of genomic matrix
#         family_phenotype_df (pd.DataFrame): Family phenotype data

# %%
gene_expression_df.head(2)
# Out:
#                 ID       symbol       expression  AAACCCAAGACTGTTC-1  \
# 0  ENSG00000243485  MIR1302-2HG  Gene Expression                   0
# 1  ENSG00000237613      FAM138A  Gene Expression                   0
#
#    AAACCCAAGGATCATA-1  AAACCCAGTTATTCTC-1  AAACCCATCATGAGGG-1  \
# 0                   0                   0                   0
# 1                   0                   0                   0
#
#    AAACGAAAGCCAGTAG-1  AAACGAAAGCTGACAG-1  AAACGAAAGTAATACG-1  ...  \
# 0                   0                   0                   0  ...
# 1                   0                   0                   0  ...
#
#    TTTGGTTAGCTTTCCC-20  TTTGGTTGTTTCGACA-20  TTTGGTTTCAGACCCG-20  \
# 0                    0                    0                    0
# 1                    0                    0                    0
#
#    TTTGGTTTCTCATAGG-20  TTTGGTTTCTGTAACG-20  TTTGTTGAGCGTCGAA-20  \
# 0                    0                    0                    0
# 1                    0                    0                    0
#
#    TTTGTTGAGTGTACCT-20  TTTGTTGCAATTGCAC-20  TTTGTTGCATTCAGCA-20  \
# 0                    0                    0                    0
# 1                    0                    0                    0
#
#    TTTGTTGGTGGGTTGA-20
# 0                    0
# 1                    0
#
# [2 rows x 72320 columns]

# %%
gene_expression_df.shape
# Out:
# (36601, 72320)

# %%
len(gene_expression_df['ID'].unique())
# Out:
# 36601

# %%
'NKG7' in gene_expression_df['symbol'].unique()
# Out:
# True

# %%
antibody_capture_df.head(2)
# Out:
#          ID          symbol        expression  AAACCCAAGACTGTTC-1  \
# 36601  CCR4  CCR4_TotalSeqB  Antibody Capture                   5
# 36602  CCR5  CCR5_TotalSeqB  Antibody Capture                   0
#
#        AAACCCAAGGATCATA-1  AAACCCAGTTATTCTC-1  AAACCCATCATGAGGG-1  \
# 36601                   0                   0                   1
# 36602                   1                   0                   0
#
#        AAACGAAAGCCAGTAG-1  AAACGAAAGCTGACAG-1  AAACGAAAGTAATACG-1  ...  \
# 36601                   0                   0                   0  ...
# 36602                   0                   1                   0  ...
#
#        TTTGGTTAGCTTTCCC-20  TTTGGTTGTTTCGACA-20  TTTGGTTTCAGACCCG-20  \
# 36601                    0                    2                    0
# 36602                    0                    0                    0
#
#        TTTGGTTTCTCATAGG-20  TTTGGTTTCTGTAACG-20  TTTGTTGAGCGTCGAA-20  \
# 36601                    0                    0                    0
# 36602                    0                    0                    0
#
#        TTTGTTGAGTGTACCT-20  TTTGTTGCAATTGCAC-20  TTTGTTGCATTCAGCA-20  \
# 36601                    0                    0                    3
# 36602                    0                    0                    0
#
#        TTTGTTGGTGGGTTGA-20
# 36601                    0
# 36602                    3
#
# [2 rows x 72320 columns]

# %%
antibody_capture_df.shape
# Out:
# (35, 72320)

# %%
antibody_capture_df['ID'].unique()
# Out:
# array(['CCR4', 'CCR5', 'CCR6', 'CCR7', 'CD11a', 'CD127', 'CD138', 'CD161',
#        'CD20', 'CD226', 'CD24', 'CD25', 'CD27', 'CD3', 'CD38', 'CD4',
#        'CD45RA', 'CD49b', 'CD49d', 'CD56', 'CD62L', 'CD71', 'CD8',
#        'CTLA-4', 'CXCR3', 'CXCR4', 'CXCR5', 'GITR', 'HLA-DR', 'ICOS',
#        'IgD', 'IgM', 'LAG3', 'TCRVa7.2', 'TCRgd'], dtype=object)

# %%
family_phenotype_df.head(2)
# Out:
#                                  title geo_accession                 status  \
# GSM7669046  Patient Placebo N1 J0, GEX    GSM7669046  Public on Oct 05 2023
# GSM7669047  Patient Placebo N1 J0, ADT    GSM7669047  Public on Oct 05 2023
#
#            submission_date last_update_date type channel_count  \
# GSM7669046     Jul 31 2023      Oct 05 2023  SRA             1
# GSM7669047     Jul 31 2023      Oct 05 2023  SRA             1
#
#            source_name_ch1  organism_ch1 taxid_ch1  ...  \
# GSM7669046           Blood  Homo sapiens      9606  ...
# GSM7669047           Blood  Homo sapiens      9606  ...
#
#            contact_zip/postal_code contact_country       instrument_model  \
# GSM7669046                   34094          France  Illumina NovaSeq 6000
# GSM7669047                   34094          France  Illumina NovaSeq 6000
#
#            library_selection              library_source library_strategy  \
# GSM7669046              cDNA  transcriptomic single cell          RNA-Seq
# GSM7669047              cDNA                       other          RNA-Seq
#
#                                                      relation  \
# GSM7669046  BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM7669047  BioSample: https://www.ncbi.nlm.nih.gov/biosam...
#
#            supplementary_file_1  series_id data_row_count
# GSM7669046                 NONE  GSE239626              0
# GSM7669047                 NONE  GSE239626              0
#
# [2 rows x 35 columns]

# %% [markdown]
# ## GSE159033

# %% [markdown]
# | GEO Accession | Provided Information | Technology Used | Type of Data | Tissue/Cell Type Analyzed | Specific Samples |
# |---------------|----------------------|------------------|--------------|----------------------------|------------------|
# | GSE159033     | Whole-transcriptome profiling in PBMCs from patients with LS-OCMB characterization reveals 4 RNAs as biomarkers of highly active disease | Non-coding RNA profiling by array, RNA-seq | Processed data (miRNA) | Peripheral blood mononuclear cells (PBMCs) | Multiple sclerosis patients with positive and negative LS-OCMB status |

# %%
from GSE159033.load_GSE159033 import load_GSE159033

genomic_matrix_df, family_phenotype_df = load_GSE159033()

# %%
help(load_GSE159033)
# Out:
# Help on function load_GSE159033 in module GSE159033.load_GSE159033:
#
# load_GSE159033()
#     Load data from GSE159033 dataset
#
#     Returns:
#         genomic_matrix_df (pd.DataFrame): Genomic matrix data
#         family_phenotype_df (pd.DataFrame): Family phenotype data

# %%
genomic_matrix_df.head(2)
# Out:
#          ID     Accession_ID     Accession Transcript ID(Array Design)  \
# 0  20500112  MIMAT0000062_st  MIMAT0000062               hsa-let-7a-5p
# 1  20500113  MIMAT0004481_st  MIMAT0004481               hsa-let-7a-3p
#
#   Sequence Type Species Scientific Name  \
# 0         miRNA            Homo sapiens
# 1         miRNA            Homo sapiens
#
#                                           Alignments  Sequence Length  \
# 0  chr11:122017276-122017297 (-) /// chr22:465086...               22
# 1  chr22:46508680-46508700 (+) /// chr9:96938295-...               21
#
#                  Sequence                                     Genome Context  \
# 0  UGAGGUAGUAGGUUGUAUAGUU  ENST00000362295 // sense // exon // 1 /// ENST...
# 1   CUAUACAAUCUACUGUCUUUC  ENST00000362295 // sense // exon // 1 /// ENST...
#
#    ... GSM4817990 GSM4817991 GSM4817992 GSM4817993 GSM4817994 GSM4817995  \
# 0  ...      10.98      12.64      11.17      11.89      11.50      11.56
# 1  ...       1.34       0.89       1.11       1.14       0.77       0.96
#
#   GSM4817996  GSM4817997  GSM4817998  GSM4817999
# 0      11.73       11.55       12.16       11.64
# 1       0.79        1.21        1.35        1.38
#
# [2 rows x 29 columns]

# %%
family_phenotype_df.head(2)
# Out:
#                         title geo_accession                 status  \
# GSM4817989  Sample04-positive    GSM4817989  Public on Dec 21 2020
# GSM4817990  Sample05-positive    GSM4817990  Public on Dec 21 2020
#
#            submission_date last_update_date type  channel_count  \
# GSM4817989     Oct 05 2020      Dec 22 2020  RNA              1
# GSM4817990     Oct 05 2020      Dec 22 2020  RNA              1
#
#            source_name_ch1  organism_ch1  taxid_ch1  ...  \
# GSM4817989           Blood  Homo sapiens       9606  ...
# GSM4817990           Blood  Homo sapiens       9606  ...
#
#                     contact_name         contact_email      contact_institute  \
# GSM4817989  Maider,,Mu̱oz-Culla  maider.munoz@ehu.eus  Biodonostia Institute
# GSM4817990  Maider,,Mu̱oz-Culla  maider.munoz@ehu.eus  Biodonostia Institute
#
#                      contact_address   contact_city contact_zip/postal_code  \
# GSM4817989  Paseo Dr.Begiristain s/n  San Sebastian                   20014
# GSM4817990  Paseo Dr.Begiristain s/n  San Sebastian                   20014
#
#            contact_country                                 supplementary_file  \
# GSM4817989           Spain  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4817...
# GSM4817990           Spain  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4817...
#
#                       series_id data_row_count
# GSM4817989  GSE159033,GSE159036           6631
# GSM4817990  GSE159033,GSE159036           6631
#
# [2 rows x 32 columns]

# %% [markdown]
# ##  GSE173787

# %% [markdown]
# ### First dataset

# %% [markdown]
# Contains 12 HC (healthy condition) patients and 17 MS (multiple sclerosis) patients.
