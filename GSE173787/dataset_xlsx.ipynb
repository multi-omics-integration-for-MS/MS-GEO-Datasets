# %%
import pandas as pd
import numpy as np
# Out:
# c:\Users\giuli\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
data_01 = pd.read_excel('pnas.2111920118.sd01.xlsx', header=1, index_col=0)
data_01
# Out:
#    Unnamed: 1  Bisulfite conversion rate  Coverage      Depth  \
# 1          HC                   0.996512  0.930774  12.938460
# 2          HC                   0.996372  0.930213  17.840417
# 3          HC                   0.996646  0.930228  17.773436
# 4          HC                   0.996599  0.930274  18.368304
# 5          HC                   0.996699  0.929747  17.377918
# 6          HC                   0.996768  0.932192  23.408974
# 7          HC                   0.996947  0.929685  15.971407
# 8          HC                   0.996898  0.928607  13.548486
# 9          HC                   0.996820  0.930086  16.368358
# 10         HC                   0.996613  0.931072  19.442724
# 11         HC                   0.992790  0.931186  21.812578
# 12         HC                   0.992276  0.930920  20.684043
# 13         MS                   0.996657  0.930324  17.984730
# 14         MS                   0.996421  0.930266  17.007209
# ...

# %%
data_02 = pd.read_excel('pnas.2111920118.sd02.xlsx')
data_02
# Out:
#    Sample ID Group  Bisulfite conversion rate  Coverage      Depth
# 0       HC-1    HC                   0.995716  0.929206  15.736371
# 1       HC-2    HC                   0.995485  0.929513  16.006528
# 2       HC-3    HC                   0.995200  0.930783  19.982329
# 3       HC-4    HC                   0.995258  0.929191  16.832175
# 4       HC-5    HC                   0.995298  0.929502  16.636607
# 5       HC-6    HC                   0.995264  0.930080  14.346573
# 6       HC-7    HC                   0.996674  0.929717  15.750571
# 7       HC-8    HC                   0.996554  0.929193  14.511543
# 8       HC-9    HC                   0.996321  0.930720  16.527435
# 9      HC-10    HC                   0.996316  0.930101  15.576498
# 10     HC-11    HC                   0.995146  0.930830  22.355377
# 11     HC-12    HC                   0.994130  0.930743  22.457742
# 12     HC-13    HC                   0.992355  0.926394  10.391535
# ...

# %%
data_03 = pd.read_excel('pnas.2111920118.sd03.xlsx')
data_03
# Out:
#                                             Sample ID Group  Dataset   Age  \
# 0                                                HC-1    HC      1.0  58.0
# 1                                                HC-2    HC      1.0  58.0
# 2                                                HC-3    HC      1.0  31.0
# 3                                                HC-4    HC      1.0  31.0
# 4                                                HC-5    HC      1.0  25.0
# 5                                                HC-6    HC      1.0  54.0
# 6                                                HC-7    HC      1.0  23.0
# 7                                                HC-8    HC      1.0  50.0
# 8                                                HC-9    HC      1.0  58.0
# 9                                               HC-10    HC      1.0  33.0
# 10                                              HC-11    HC      1.0  33.0
# ...

# %%
data_04 = pd.read_excel('pnas.2111920118.sd04.xlsx')
data_04
# Out:
#      Hypo-DMR assigned genes Hyper-DMR assigned genes
# 0                       A1BG                     A1BG
# 1                     A4GALT                    ABCC4
# 2                       AACS                    ABCG1
# 3                    AADACL2                   ADAM17
# 4                       AAK1                  ADAMTS9
# ...                      ...                      ...
# 5252                  ZSWIM6                      NaN
# 5253                  ZWILCH                      NaN
# 5254                   ZWINT                      NaN
# 5255                  ZYG11A                      NaN
# 5256                   ZZEF1                      NaN
#
# [5257 rows x 2 columns]

# %%
data_05 = pd.read_excel('pnas.2111920118.sd05.xlsx')
data_05
# Out:
#    Transcription factors  P-value
# 0                   BATF        0
# 1                   JUNB        0
# 2                   ATF3        0
# 3                  MEF2A        0
# 4                   IRF3        0
# 5                  MEF2B        0
# 6                  MEF2C        0
# 7                   IRF4        0
# 8                   USF2        0
# 9                   PAX5        0
# 10                  MAFK        0
# 11                 BACH1        0
# 12                   MAX        0
# 13                  ATF7        0
# 14                  PAX8        0
# 15                  ZEB1        0

# %%
data_06 = pd.read_excel('pnas.2111920118.sd06.xlsx')
data_06
# Out:
#       Factor P-value Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5 Unnamed: 6  \
# 0        NaN    up2k     up1.5k       up1k     up0.5k  hyper-DMRs   down0.5k
# 1    EWS:ERG       1          1          1          1       0.001          1
# 2      HOXC9     0.1          1          1          1       0.001       0.01
# 3        SCL       1          1          1          1       0.001          1
# 4      ASCL1     0.1          1          1          1        0.01          1
# 5      ATOH1       1          1          1          1        0.01          1
# 6       CMYC       1          1          1        0.1        0.01          1
# 7        DUX       1          1          1          1        0.01          1
# 8       ER71       1          1          1          1        0.01          1
# 9        ERG       1          1          1          1        0.01          1
# 10      ETS1       1          1          1          1        0.01          1
# ...

# %%
data_07 = pd.read_excel('pnas.2111920118.sd07.xlsx')
data_07
# Out:
#    TSS-proximal DMR-coupled genes TSS-dital-10k DMR-coupled genes  \
# 0                         IL12RB1                           GRAP2
# 1                           RUNX3                           RUNX3
# 2                          CARD11                          ZBTB38
# 3                            GRB2                            GGA3
# 4                           ZPBP2                           NPAS1
# ..                            ...                             ...
# 71                            NaN                             NaN
# 72                            NaN                             NaN
# 73                            NaN                             NaN
# 74                            NaN                             NaN
# 75                            NaN                             NaN
#
#    TSS-dital-100k DMR-coupled genes
# 0                             TNIP3
# 1                             TUBD1
# 2                               ERG
# ...

# %%
# read data
data_08 = pd.read_excel('pnas.2111920118.sd08.xlsx')
data_08
# Out:
#      Gene name     logFC    logCPM       P value       FDR
# 0     ARHGAP31  0.819578  4.471801  9.720000e-05  0.006011
# 1        TRIB1  1.508544  6.125172  9.500000e-05  0.005918
# 2         E2F2  1.757939  3.132182  9.460000e-06  0.001635
# 3       TAPBPL  0.625243  4.549739  9.110000e-05  0.005695
# 4        MYO1D  1.491649  4.945613  9.100000e-07  0.000398
# ..         ...       ...       ...           ...       ...
# 542      APBB1 -0.695130  4.786609  1.269600e-04  0.007116
# 543       H1-3 -2.155091  1.245875  1.258320e-04  0.007116
# 544       BEX4 -0.709985  4.886337  1.213630e-04  0.007106
# 545  SECISBP2L -0.581726  7.028738  1.190150e-04  0.006997
# 546       RCN2 -0.687891  5.345495  1.018960e-04  0.006207
#
# [547 rows x 5 columns]

# %%
data_09 = pd.read_excel('pnas.2111920118.sd09.xlsx')
data_09
# Out:
#         GroupID                 Category        Term  \
# 0     1_Summary  GO Biological Processes  GO:0006958
# 1      1_Member  GO Biological Processes  GO:0006958
# 2      1_Member  GO Biological Processes  GO:0002455
# 3      1_Member  GO Biological Processes  GO:0016064
# 4      1_Member  GO Biological Processes  GO:0019724
# ..          ...                      ...         ...
# 292  19_Summary  GO Biological Processes  GO:0007219
# 293   19_Member  GO Biological Processes  GO:0007219
# 294   19_Member  GO Biological Processes  GO:0007221
# 295  20_Summary  GO Biological Processes  GO:1904587
# 296   20_Member  GO Biological Processes  GO:1904587
#
#                                            Description       LogP  \
# 0             complement activation, classical pathway -48.304348
# 1             complement activation, classical pathway -48.304348
# 2    humoral immune response mediated by circulatin... -47.484893
# ...

# %%
data_10 = pd.read_excel('pnas.2111920118.sd10.xlsx')
data_10
# Out:
#         GroupID                 Category        Term  \
# 0     1_Summary  GO Biological Processes  GO:0006334
# 1      1_Member  GO Biological Processes  GO:0006334
# 2      1_Member  GO Biological Processes  GO:0016584
# 3      1_Member  GO Biological Processes  GO:0031497
# 4      1_Member  GO Biological Processes  GO:0031936
# ..          ...                      ...         ...
# 135   19_Member  GO Biological Processes  GO:0044089
# 136   19_Member  GO Biological Processes  GO:0043254
# 137  20_Summary  GO Biological Processes  GO:0007050
# 138   20_Member  GO Biological Processes  GO:0007050
# 139   20_Member  GO Biological Processes  GO:0045786
#
#                                            Description      LogP  \
# 0                                  nucleosome assembly -6.432346
# 1                                  nucleosome assembly -6.432346
# 2                               nucleosome positioning -6.133274
# ...

# %%
data_11 = pd.read_excel('pnas.2111920118.sd11.xlsx')
data_11
# Out:
#    Gene_name                                           GeneDesc  \
# 0      HJURP                                                  #
# 1     RNF168                     RING-type (C3HC4) zinc fingers
# 2        TTK                                                  #
# 3      PRDM1                            Zinc fingers, C2H2-type
# 4      GFI1B                            Zinc fingers, C2H2-type
# 5        VDR                          Nuclear hormone receptors
# 6        CIT                                                  #
# 7      AURKB  Serine/threonine phosphatases / Protein phosph...
# 8       CDC6                                                  #
# 9      TOP2A                                                  #
# 10     KEAP1            Kelch-like, "BTB/POZ domain containing"
# 11     ASF1B                                                  #
# 12  APOBEC3B              Apolipoprotein B mRNA editing enzymes
# 13     KDM5B  Chromatin-modifying enzymes / K-demethylases, ...
# ...

# %%
data_12 = pd.read_excel('pnas.2111920118.sd12.xlsx')
data_12
# Out:
#         GroupID                 Category        Term  \
# 0     1_Summary  GO Biological Processes  GO:0046649
# 1      1_Member  GO Biological Processes  GO:0046649
# 2      1_Member  GO Biological Processes  GO:0030217
# 3      1_Member  GO Biological Processes  GO:0030098
# 4      1_Member  GO Biological Processes  GO:0002521
# ..          ...                      ...         ...
# 164   19_Member  GO Biological Processes  GO:0030278
# 165  20_Summary  GO Biological Processes  GO:0016485
# 166   20_Member  GO Biological Processes  GO:0016485
# 167   20_Member  GO Biological Processes  GO:0045862
# 168   20_Member  GO Biological Processes  GO:0002576
#
#                             Description      LogP  Log(q-value) InTerm_InList  \
# 0                 lymphocyte activation -4.317160     -0.543740        11/754
# 1                 lymphocyte activation -4.317160     -0.543740        11/754
# 2                T cell differentiation -3.719172     -0.543740         6/246
# ...

# %%
data_13 = pd.read_excel('pnas.2111920118.sd13.xlsx')
data_13
# Out:
#   Cytokines HC Mean+/-SD (pg/mL) MS Mean+/-SD (pg/mL)  P-value (MS vs HC)
# 0     TRAIL        76.63+/-25.83        82.18+/-27.87              0.5250
# 1      BAFF       259.66+/-40.73       241.36+/-47.18              0.3424
# 2       IL6        21.92+/-70.82          1.66+/-3.52              0.7113
# 3      IL10          0.82+/-0.57          2.11+/-4.81              0.4027

# %%
data_14 = pd.read_excel('pnas.2111920118.sd14.xlsx')
data_14
# Out:
#                Name      Sequence (5'>3')
# 0  pSEMA4A for       GCCCCAGACTCATGGTGCCT
# 1   pSEMA4A rev      GTCAGCTGGGGCCCATTCCT
# 2  pPRDM1 for        GCTTTGATGAAGCCACATGT
# 3        pPRDM1 rev  ACTTCAGTTCCGATTATGCT
# 4     pTNFRSF17 for  ACTGTGGATTTTTAAAATGG
# 5     pTNFRSF17 rev  GAACTTCGCCTGCTTCGTGG
# 6       pDCAF12 for  GAGCACCTGTAATCTGAGCT
# 7       pDCAF12 rev  TGACCTGCCATCTAAACCAC
# 8        pZWINT for  TGAGACGGAGTCTCGCACTG
# 9        pZWINT rev  CCTAAGATTACTTTGAAGTC
