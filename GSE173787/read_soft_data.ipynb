# %%
import GEOparse
import pandas as pd
# Out:
# c:\Users\giuli\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
DATA_PATH = 'GSE173787_family.soft/GSE173787_family.soft'

# %%
# read data
gse = GEOparse.get_GEO(filepath=DATA_PATH)
gse
# Out:
# 16-Apr-2024 17:00:55 INFO GEOparse - Parsing GSE173787_family.soft/GSE173787_family.soft:
# 16-Apr-2024 17:00:55 DEBUG GEOparse - DATABASE: GeoMiame
# 16-Apr-2024 17:00:55 DEBUG GEOparse - SERIES: GSE173787
# 16-Apr-2024 17:00:55 DEBUG GEOparse - PLATFORM: GPL24676
# 16-Apr-2024 17:00:55 DEBUG GEOparse - SAMPLE: GSM5278397
# 16-Apr-2024 17:00:55 DEBUG GEOparse - SAMPLE: GSM5278398
# 16-Apr-2024 17:00:55 DEBUG GEOparse - SAMPLE: GSM5278399
# 16-Apr-2024 17:00:55 DEBUG GEOparse - SAMPLE: GSM5278400
# 16-Apr-2024 17:00:55 DEBUG GEOparse - SAMPLE: GSM5278401
# 16-Apr-2024 17:00:55 DEBUG GEOparse - SAMPLE: GSM5278402
# 16-Apr-2024 17:00:55 DEBUG GEOparse - SAMPLE: GSM5278403
# 16-Apr-2024 17:00:55 DEBUG GEOparse - SAMPLE: GSM5278404
# 16-Apr-2024 17:00:55 DEBUG GEOparse - SAMPLE: GSM5278405
# 16-Apr-2024 17:00:55 DEBUG GEOparse - SAMPLE: GSM5278406
# 16-Apr-2024 17:00:55 DEBUG GEOparse - SAMPLE: GSM5278407
# 16-Apr-2024 17:00:55 DEBUG GEOparse - SAMPLE: GSM5278408
# ...

# %%
gse.phenotype_data.head(2)
# Out:
#                        title geo_accession                 status  \
# GSM5278397  MS-1-CD19 BS-Seq    GSM5278397  Public on Jan 18 2022
# GSM5278398  MS-2-CD19 BS-Seq    GSM5278398  Public on Jan 18 2022
#
#            submission_date last_update_date type channel_count  \
# GSM5278397     May 03 2021      Jan 18 2022  SRA             1
# GSM5278398     May 03 2021      Jan 18 2022  SRA             1
#
#              source_name_ch1  organism_ch1 taxid_ch1  ...  \
# GSM5278397  peripheral blood  Homo sapiens      9606  ...
# GSM5278398  peripheral blood  Homo sapiens      9606  ...
#
#            contact_zip/postal_code contact_country       instrument_model  \
# GSM5278397                   94158             USA  Illumina NovaSeq 6000
# GSM5278398                   94158             USA  Illumina NovaSeq 6000
#
#            library_selection library_source library_strategy  \
# GSM5278397            RANDOM        genomic    Bisulfite-Seq
# ...

# %%
MATRIX_PATH = 'GSE173787_series_matrix.txt/GSE173787_series_matrix.txt'

# %%
headers = []
with open(MATRIX_PATH) as f:
    for i, line in enumerate(f):
        if i >= 27:
            header = line.split('!').split('\t')[0]
            headers.append(header)

headers
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 5
#       3     for i, line in enumerate(f):
#       4         if i >= 27:
# ----> 5             header = line.split('!').split('\t')[0]
#       6             headers.append(header)
#       8 headers
#
# AttributeError: 'list' object has no attribute 'split'

# %%
# read the file from line 28, header is the first string after ! and after I have the value of the columns


# read the data
data = pd.read_csv(MATRIX_PATH, sep='\t', skiprows=28, header=None)
data.columns = header
data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 5
#       3     for i, line in enumerate(f):
#       4         if i >= 27:
# ----> 5             header = line.split('!').split('\t')[0]
#       6             break
#       8 # read the data
#
# AttributeError: 'list' object has no attribute 'split'
